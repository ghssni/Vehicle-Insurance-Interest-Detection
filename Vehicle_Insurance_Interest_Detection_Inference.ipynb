# %% [markdown]
# # Model Inference

# %% [markdown]
# Nama : Ghassani Nurbaningtyas
#
# Batch : SBY-003
#
# Model yang telah dilatih akan dilakukan tes pada data yang tidak termasuk pada train dan tes set. Datanya harus dengan format yang original, bukan data yang telah dilakukan scaling ataupun encoding.

# %% [markdown]
# # Import Libraries

# %%
import pickle
import pandas as pd
import numpy as np

# %% [markdown]
# # Load Files

# %%
# Load file model

with open('svc_gridcv_best.pkl', 'rb') as file_1:
  svc_gridcv_best = pickle.load(file_1)

# %% [markdown]
# # Data Inference

# %%
  data = {'id': {0: 1, 1: 2, 2: 3, 3: 4, 4: 5},
 'gender': {0: 'Male', 1: 'Male', 2: 'Male', 3: 'Male', 4: 'Female'},
 'age': {0: 44, 1: 76, 2: 47, 3: 21, 4: 29},
 'driving_license': {0: 1, 1: 1, 2: 1, 3: 1, 4: 1},
 'region_code': {0: 28.0, 1: 3.0, 2: 28.0, 3: 11.0, 4: 41.0},
 'previously_insured': {0: 0, 1: 0, 2: 0, 3: 1, 4: 1},
 'vehicle_age': {0: '> 2 Years',
  1: '1-2 Year',
  2: '> 2 Years',
  3: '< 1 Year',
  4: '< 1 Year'},
 'vehicle_damage': {0: 'Yes', 1: 'No', 2: 'Yes', 3: 'No', 4: 'No'},
 'annual_premium': {0: 40454.0,
  1: 33536.0,
  2: 38294.0,
  3: 28619.0,
  4: 27496.0},
 'policy_sales_channel': {0: 26.0, 1: 26.0, 2: 26.0, 3: 152.0, 4: 152.0},
 'vintage': {0: 217, 1: 183, 2: 27, 3: 203, 4: 39},
 'reg_code_cat': {0: 'high chance',
  1: 'medium chance',
  2: 'high chance',
  3: 'medium chance',
  4: 'medium chance'},
 'policy_sales_channel_cat': {0: 'small chance',
  1: 'small chance',
  2: 'small chance',
  3: 'small chance',
  4: 'small chance'},
 'age_cat': {0: 'adult',
  1: 'old',
  2: 'middle old',
  3: 'young adult',
  4: 'adult'},
 'response': {0: 1, 1: 0, 2: 1, 3: 0, 4: 0}
  }

# %%
data_inf = pd.DataFrame(data)

# %%
data_inf
# Out:
#    id  gender  age  driving_license  region_code  previously_insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   vehicle_age vehicle_damage  annual_premium  policy_sales_channel  vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#     reg_code_cat policy_sales_channel_cat      age_cat  response
# ...

# %% [markdown]
# # Predict

# %%
y_pred_new_proba = svc_gridcv_best.predict_proba(data_inf)
y_pred_new_test = np.where(y_pred_new_proba[:,1] >= 0.9, 1, 0)

# %% [markdown]
# # Merge to Dataset

# %%
data_inf['predict'] = y_pred_new_test

# %%
data_inf
# Out:
#    id  gender  age  driving_license  region_code  previously_insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   vehicle_age vehicle_damage  annual_premium  policy_sales_channel  vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#     reg_code_cat policy_sales_channel_cat      age_cat  response  predict
# ...

# %% [markdown]
# # Insight

# %% [markdown]
# Model terbaik pilihan saya adalah SVC karena performa pada precisionnya paling tinggi pada train parameter default. Setelah dilakukan inference menggunakan model SVC, model berhasil memprediksi data inference seperti yang ditampilkan pada kolom predict diatas.
